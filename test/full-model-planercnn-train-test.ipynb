# %%
import os
os.chdir('..')

# %%
from fox.config import Config
from fox.dataset import ComboDataset
# from fox.model_yolo import Model
from fox.model import Model
from fox.train import train
import matplotlib.pyplot as plt
import torch
import pytorch_lightning as pl

from fox.yolov3.utils.datasets import LoadImagesAndLabels
from fox.utils import parse_data_cfg

# %%
c = Config(USE_YOLO=False, BATCH_SIZE=2, EPOCHS=4)
c.planercnn_config.PREDICT_DEPTH = False
# c.LOG_RES_EVERY_N_BATCHES = 1
d = ComboDataset(c)
loader = torch.utils.data.DataLoader(d, batch_size=2, shuffle=True, collate_fn=d.collate_fn)
loader_val = torch.utils.data.DataLoader(ComboDataset(c, train=False), batch_size=2, collate_fn=d.collate_fn)
# Out:
# Caching labels data/mini/yolo/train.txt (64 found, 0 missing, 0 empty, 0 duplicate, for 64 images): 100%|██████████| 64/64 [00:00<00:00, 1208.06it/s]
# Caching labels data/mini/yolo/test.txt (5 found, 0 missing, 0 empty, 0 duplicate, for 5 images): 100%|██████████| 5/5 [00:00<00:00, 1895.47it/s]

# %%
# model = Model(c, len(loader), 4, d.yolo_labels)
model = Model(c, len(loader), 4, d.yolo_dataset.yolo_labels)
# Out:
# Using cache found in /home/ouroboros/.cache/torch/hub/facebookresearch_WSL-Images_master
# Loading weights:  weights/midas.pt

# %%
trainer = pl.Trainer(
    max_epochs=c.EPOCHS,
    gpus=1,
    automatic_optimization=False,
)
trainer.fit(
    model,
    train_dataloader=loader,
    val_dataloaders=loader_val,
    
)
# Out:
# Epoch 0:  91%|█████████▏| 32/35 [01:15<00:07,  2.36s/it, v_num=18, total loss=7.5, midas loss=3.92e+3, planercnn loss=3.57]
# Validating: 0it [00:00, ?it/s]
# Epoch 0:  97%|█████████▋| 34/35 [01:17<00:02,  2.27s/it, v_num=18, total loss=7.5, midas loss=3.92e+3, planercnn loss=3.57]
# Validating:  67%|██████▋   | 2/3 [00:04<00:01,  1.88s/it]
# Epoch 0: 100%|██████████| 35/35 [01:32<00:00,  2.64s/it, v_num=18, total loss=7.5, midas loss=3.92e+3, planercnn loss=3.57]
# Epoch 1:  91%|█████████▏| 32/35 [01:04<00:06,  2.01s/it, v_num=18, total loss=6.57, midas loss=2.97e+3, planercnn loss=3.6, avg planercnn loss=3.85, avg midas loss=3.52e+3, avg total loss=7.37]
# Validating: 0it [00:00, ?it/s]
# Epoch 1:  97%|█████████▋| 34/35 [01:05<00:01,  1.93s/it, v_num=18, total loss=6.57, midas loss=2.97e+3, planercnn loss=3.6, avg planercnn loss=3.85, avg midas loss=3.52e+3, avg total loss=7.37]
# Validating:  67%|██████▋   | 2/3 [00:04<00:01,  1.86s/it]
# Epoch 1: 100%|██████████| 35/35 [01:21<00:00,  2.33s/it, v_num=18, total loss=6.57, midas loss=2.97e+3, planercnn loss=3.6, avg planercnn loss=3.85, avg midas loss=3.52e+3, avg total loss=7.37]
# Epoch 2:  91%|█████████▏| 32/35 [01:10<00:06,  2.22s/it, v_num=18, total loss=6.84, midas loss=3.46e+3, planercnn loss=3.37, avg planercnn loss=3.75, avg midas loss=3.5e+3, avg total loss=7.25]
# Validating: 0it [00:00, ?it/s]
# Epoch 2:  97%|█████████▋| 34/35 [01:12<00:02,  2.14s/it, v_num=18, total loss=6.84, midas loss=3.46e+3, planercnn loss=3.37, avg planercnn loss=3.75, avg midas loss=3.5e+3, avg total loss=7.25]
# Validating:  67%|██████▋   | 2/3 [00:04<00:01,  1.97s/it]
# Epoch 2: 100%|██████████| 35/35 [01:26<00:00,  2.47s/it, v_num=18, total loss=6.84, midas loss=3.46e+3, planercnn loss=3.37, avg planercnn loss=3.75, avg midas loss=3.5e+3, avg total loss=7.25]
# Epoch 3:  20%|██        | 7/35 [00:13<00:55,  1.98s/it, v_num=18, total loss=7.03, midas loss=3.18e+3, planercnn loss=3.85, avg planercnn loss=3.61, avg midas loss=3.52e+3, avg total loss=7.13]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py in train(self)
#     493                 # run train epoch
# --> 494                 self.train_loop.run_training_epoch()
#     495
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py in run_training_epoch(self)
#     560             # ------------------------------------
# --> 561             batch_output = self.run_training_batch(batch, batch_idx, dataloader_idx)
#     562
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py in run_training_batch(self, batch, batch_idx, dataloader_idx)
#     730                     else:
# --> 731                         self._curr_step_result = self.training_step(split_batch, batch_idx, opt_idx, self.trainer.hiddens)
#     732
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py in training_step(self, split_batch, batch_idx, opt_idx, hiddens)
#     319             args = self.build_train_args(split_batch, batch_idx, opt_idx, hiddens)
# --> 320             training_step_output = self.trainer.accelerator_backend.training_step(args)
#     321             self._check_training_step_output(training_step_output)
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/accelerators/gpu_accelerator.py in training_step(self, args)
#      71         else:
# ---> 72             output = self.__training_step(args)
#      73
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/accelerators/gpu_accelerator.py in __training_step(self, args)
#      79         args[0] = batch
# ---> 80         output = self.trainer.model.training_step(*args)
#      81         return output
#
# /d/Users/shyam/Projects/eva5-final/fox/model.py in training_step(self, batch, batch_idx)
#     265         midas_out, yolo_out, planercnn_out = self(
# --> 266             imgs, planercnn_data=planercnn_forward_prop_data
#     267         )
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#
# /d/Users/shyam/Projects/eva5-final/fox/model.py in forward(self, x, planercnn_data, yolo_ema)
#     228                 use_refinement="refinement"
# --> 229                 in self.config.planercnn_config.options.suffix,
#     230             )
#
# /d/Users/shyam/Projects/eva5-final/fox/planercnn/models/model.py in predict_on_batch(self, extractor_outputs, inputs, mode, use_nms, use_refinement, return_feature_map)
#    1711                 use_refinement,
# -> 1712                 return_feature_map
#    1713             ))
#
# /d/Users/shyam/Projects/eva5-final/fox/planercnn/models/model.py in predict(self, input, mode, use_nms, use_refinement, return_feature_map)
#    1749         else:
# -> 1750             depth_np = torch.ones((1, self.config.IMAGE_MAX_DIM, self.config.IMAGE_MAX_DIM)).cuda()
#    1751             pass
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-414978d6283e> in <module>
#       7     model,
#       8     train_dataloader=loader,
# ----> 9     val_dataloaders=loader_val,
#      10
#      11 )
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloader, val_dataloaders, datamodule)
#     443         self.call_hook('on_fit_start')
#     444
# --> 445         results = self.accelerator_backend.train()
#     446         self.accelerator_backend.teardown()
#     447
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/accelerators/gpu_accelerator.py in train(self)
#      62
#      63         # train or test
# ---> 64         results = self.train_or_test()
#      65         return results
#      66
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/accelerators/accelerator.py in train_or_test(self)
#      64             results = self.trainer.run_test()
#      65         else:
# ---> 66             results = self.trainer.train()
#      67         return results
#      68
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py in train(self)
#     531
#     532                 # hook
# --> 533                 self.train_loop.on_train_end()
#     534
#     535     def run_evaluation(self, test_mode: bool = False, max_batches=None):
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py in on_train_end(self)
#     188         # when a checkpoint was saved at the last step
#     189         self.trainer.global_step -= 1
# --> 190         self.check_checkpoint_callback(should_save=True, is_last=True)
#     191         self.trainer.global_step += 1
#     192
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py in check_checkpoint_callback(self, should_save, is_last)
#     218                 rank_zero_info("Saving latest checkpoint...")
#     219             model = self.trainer.get_model()
# --> 220             [c.on_validation_end(self.trainer, model) for c in checkpoint_callbacks]
#     221
#     222     def on_train_epoch_start(self, epoch):
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py in <listcomp>(.0)
#     218                 rank_zero_info("Saving latest checkpoint...")
#     219             model = self.trainer.get_model()
# --> 220             [c.on_validation_end(self.trainer, model) for c in checkpoint_callbacks]
#     221
#     222     def on_train_epoch_start(self, epoch):
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/callbacks/model_checkpoint.py in on_validation_end(self, trainer, pl_module)
#     184         checkpoints can be saved at the end of the val loop
#     185         """
# --> 186         self.save_checkpoint(trainer, pl_module)
#     187
#     188     def on_save_checkpoint(self, trainer, pl_module) -> Dict[str, Any]:
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/callbacks/model_checkpoint.py in save_checkpoint(self, trainer, pl_module)
#     233
#     234         # Mode 2: save the last checkpoint
# --> 235         self._save_last_checkpoint(trainer, pl_module, epoch, monitor_candidates, filepath)
#     236
#     237     def __validate_init_configuration(self):
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/callbacks/model_checkpoint.py in _save_last_checkpoint(self, trainer, pl_module, epoch, ckpt_name_metrics, filepath)
#     512             last_filepath = os.path.join(self.dirpath, f"{last_filepath}.ckpt")
#     513
# --> 514         self._save_model(last_filepath, trainer, pl_module)
#     515         if (
#     516                 self.last_model_path
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/callbacks/model_checkpoint.py in _save_model(self, filepath, trainer, pl_module)
#     331         # delegate the saving to the trainer
#     332         if self.save_function is not None:
# --> 333             self.save_function(filepath, self.save_weights_only)
#     334         else:
#     335             raise ValueError(".save_function() not set")
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/properties.py in save_checkpoint(self, filepath, weights_only)
#     205
#     206     def save_checkpoint(self, filepath, weights_only: bool = False):
# --> 207         self.checkpoint_connector.save_checkpoint(filepath, weights_only)
#     208
#     209     def get_model(self):
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py in save_checkpoint(self, filepath, weights_only)
#     391             # write the checkpoint dictionary on the file
#     392             try:
# --> 393                 atomic_save(checkpoint, filepath)
#     394             except AttributeError as err:
#     395                 if LightningModule.CHECKPOINT_HYPER_PARAMS_KEY in checkpoint:
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/pytorch_lightning/utilities/cloud_io.py in atomic_save(checkpoint, filepath)
#      60         torch.save(checkpoint, bytesbuffer, _use_new_zipfile_serialization=False)
#      61     else:
# ---> 62         torch.save(checkpoint, bytesbuffer)
#      63     with fsspec.open(filepath, "wb") as f:
#      64         f.write(bytesbuffer.getvalue())
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     370         if _use_new_zipfile_serialization:
#     371             with _open_zipfile_writer(opened_file) as opened_zipfile:
# --> 372                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     373                 return
#     374         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     474     pickler = pickle_module.Pickler(data_buf, protocol=pickle_protocol)
#     475     pickler.persistent_id = persistent_id
# --> 476     pickler.dump(obj)
#     477     data_value = data_buf.getvalue()
#     478     zip_file.write_record('data.pkl', data_value, len(data_value))
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/site-packages/torch/tensor.py in __reduce_ex__(self, proto)
#      83     def __reduce_ex__(self, proto):
#      84         relevant_args = (self,)
# ---> 85         from torch.overrides import has_torch_function, handle_torch_function
#      86         if type(self) is not Tensor and has_torch_function(relevant_args):
#      87             return handle_torch_function(Tensor.__reduce_ex__, relevant_args, self, proto)
#
# ~/miniconda3/envs/eva5-final/lib/python3.6/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:
