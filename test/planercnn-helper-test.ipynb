# %%
import os
os.chdir('..')

# %%
from eva5_final.planercnn.models.refinement_net import RefineModel
from eva5_final.planercnn.eva5_helper import PlaneRCNNTrainer
from eva5_final.config import PlaneRCNNConfig
import torch
import matplotlib.pyplot as plt

# %%
c = PlaneRCNNConfig()
refine_model = RefineModel(c.options).cuda()
trainer = PlaneRCNNTrainer(c, refine_model)

# %%
data = torch.load('test/dummy-inputs.data')
outputs = data['outputs']
batch = data['batch']

# %%
data.keys()
# Out:
# dict_keys(['batch', 'outputs'])

# %%
trainer.train_step(batch, outputs)
# Out:
# tensor([7.2402], device='cuda:0', grad_fn=<AddBackward0>)

# %%
plt.imshow(batch[0][0].permute(1, 2, 0).cpu().numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
